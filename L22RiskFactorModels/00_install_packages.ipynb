# %% [markdown]
# # Install libraries for all code exercises in this lesson
#
# It takes about 8 to 9 minutes to install the libraries that are used in the exercises of this lesson.  To make your learning experience a bit smoother, please open this page in a new tab and run this code cell to install, then in your original page, continue onto the next video as the installation is running.  You should only have to install once for this lesson.  If you do "menu"->"reset data" at some point, you will have to reinstall the libraries again.

# %%
import sys
#!{sys.executable} -m pip install -i  https://pypi.tuna.tsinghua.edu.cn/simple/ -r requirements.txt
# !{sys.executable} -m pip install -i  https://pypi.tuna.tsinghua.edu.cn/simple/ zipline
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Collecting zipline
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/be/59/8c5802a7897c1095fdc409fb557f04df8f75c37174e80d2ba58c8d8a6488/zipline-1.3.0.tar.gz (2.5 MB)
#      |████████████████████████████████| 2.5 MB 140 kB/s eta 0:00:01     |████████▍                       | 645 kB 36 kB/s eta 0:00:50
#     ERROR: Command errored out with exit status 1:
#      command: /root/anaconda3/envs/uda/bin/python3 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-xlvydpg2/zipline/setup.py'"'"'; __file__='"'"'/tmp/pip-install-xlvydpg2/zipline/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-install-xlvydpg2/zipline/pip-egg-info
#          cwd: /tmp/pip-install-xlvydpg2/zipline/
#     Complete output (82 lines):
#     ERROR: Exception:
#     Traceback (most recent call last):
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_vendor/urllib3/response.py", line 425, in _error_catcher
#         yield
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_vendor/urllib3/response.py", line 507, in read
#         data = self._fp.read(amt) if not fp_closed else b""
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_vendor/cachecontrol/filewrapper.py", line 62, in read
#         data = self.__fp.read(amt)
#       File "/root/anaconda3/envs/uda/lib/python3.7/http/client.py", line 457, in read
#         n = self.readinto(b)
#       File "/root/anaconda3/envs/uda/lib/python3.7/http/client.py", line 501, in readinto
#         n = self.fp.readinto(b)
#       File "/root/anaconda3/envs/uda/lib/python3.7/socket.py", line 589, in readinto
#         return self._sock.recv_into(b)
#       File "/root/anaconda3/envs/uda/lib/python3.7/ssl.py", line 1071, in recv_into
#         return self.read(nbytes, buffer)
#       File "/root/anaconda3/envs/uda/lib/python3.7/ssl.py", line 929, in read
#         return self._sslobj.read(len, buffer)
#     socket.timeout: The read operation timed out
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_internal/cli/base_command.py", line 186, in _main
#         status = self.run(options, args)
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_internal/commands/wheel.py", line 161, in run
#         resolver.resolve(requirement_set)
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_internal/legacy_resolve.py", line 177, in resolve
#         discovered_reqs.extend(self._resolve_one(requirement_set, req))
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_internal/legacy_resolve.py", line 333, in _resolve_one
#         abstract_dist = self._get_abstract_dist_for(req_to_install)
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_internal/legacy_resolve.py", line 282, in _get_abstract_dist_for
#         abstract_dist = self.preparer.prepare_linked_requirement(req)
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_internal/operations/prepare.py", line 482, in prepare_linked_requirement
#         hashes=hashes,
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_internal/operations/prepare.py", line 287, in unpack_url
#         hashes=hashes,
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_internal/operations/prepare.py", line 159, in unpack_http_url
#         link, downloader, temp_dir.path, hashes
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_internal/operations/prepare.py", line 303, in _download_http_url
#         for chunk in download.chunks:
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_internal/network/utils.py", line 39, in response_chunks
#         decode_content=False,
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_vendor/urllib3/response.py", line 564, in stream
#         data = self.read(amt=amt, decode_content=decode_content)
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_vendor/urllib3/response.py", line 529, in read
#         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#       File "/root/anaconda3/envs/uda/lib/python3.7/contextlib.py", line 130, in __exit__
#         self.gen.throw(type, value, traceback)
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pip/_vendor/urllib3/response.py", line 430, in _error_catcher
#         raise ReadTimeoutError(self._pool, None, "Read timed out.")
#     pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
#     Traceback (most recent call last):
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/setuptools/installer.py", line 128, in fetch_build_egg
#         subprocess.check_call(cmd)
#       File "/root/anaconda3/envs/uda/lib/python3.7/subprocess.py", line 363, in check_call
#         raise CalledProcessError(retcode, cmd)
#     subprocess.CalledProcessError: Command '['/root/anaconda3/envs/uda/bin/python3', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', '/tmp/tmpbs4fa21s', '--quiet', 'numpy>=1.11.1']' returned non-zero exit status 2.
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-xlvydpg2/zipline/setup.py", line 323, in <module>
#         **conditional_arguments
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/setuptools/__init__.py", line 143, in setup
#         _install_setup_requires(attrs)
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/setuptools/__init__.py", line 138, in _install_setup_requires
#         dist.fetch_build_eggs(dist.setup_requires)
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/setuptools/dist.py", line 698, in fetch_build_eggs
#         replace_conflicting=True,
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pkg_resources/__init__.py", line 783, in resolve
#         replace_conflicting=replace_conflicting
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pkg_resources/__init__.py", line 1066, in best_match
#         return self.obtain(req, installer)
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/pkg_resources/__init__.py", line 1078, in obtain
#         return installer(requirement)
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/setuptools/dist.py", line 754, in fetch_build_egg
#         return fetch_build_egg(self, req)
#       File "/root/anaconda3/envs/uda/lib/python3.7/site-packages/setuptools/installer.py", line 130, in fetch_build_egg
#         raise DistutilsError(str(e))
#     distutils.errors.DistutilsError: Command '['/root/anaconda3/envs/uda/bin/python3', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', '/tmp/tmpbs4fa21s', '--quiet', 'numpy>=1.11.1']' returned non-zero exit status 2.
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
